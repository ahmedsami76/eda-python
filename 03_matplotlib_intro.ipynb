# %% [markdown]
# # Introduction to matplotlib
#
#
# ## Import Modules

# %%
# !pip install matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot([.2, .4, .6], [1, 2, 3])

# %%
plt.plot([1, 2, 3], [.2, .4, .6])
plt.plot([0.1, 0.3, 0.7])
plt.show

# %%
plt.show() # the figure is gone

# %%
plt.axis([0,5,0,20])
plt.title('My first plot')
plt.plot([1,2,3,4], [1,4,9,16], 'ro')

# %%
# matplotlib and NumPy

t = np.arange(0, 2.50, 0.1)
y1 = np.sin(np.pi * t)
y2 = np.sin(np.pi * t + np.pi/2)
y3 = np.sin(np.pi * t - np.pi/2)
plt.plot(t, y1, 'b*', t, y2, 'g^', t, y3, 'ys')

# %%
# matplotlib and NumPy

t = np.arange(0, 2.50, 0.1)
y1 = np.sin(np.pi * t)
y2 = np.sin(np.pi * t + np.pi/2)
y3 = np.sin(np.pi * t - np.pi/2)
plt.plot(t, y1, 'b--', t, y2, 'g', t, y3, 'y-')

# %%
plt.plot([1, 2, 4, 2, 1, 0, 1, 2, 1, 4], linewidth=5.0)

# %% [markdown]
# https://realpython.com/python-matplotlib-guide/#the-matplotlib-object-hierarchy
# https://matplotlib.org/stable/users/explain/quick_start.html

# %% [markdown]
# ![Figure Anatomy](images/anatomy.webp)

# %% [markdown]
# ## Overview
#
# matplotlib has 2 main styles of programming.
#
# The first or classic is the STATEFUL style which is based on MATLAB.
#
# The second approach is the OBJECT ORIENTED STYLE approach.
#
# ## Stateful or MATLAB style
#
# * step 1: initiate the figure
# * step 2: specify the subplot that contains the data
# * step 3: populate the data within the plot (plot the data)
# * step 4: show the figure
#
# Let's begin with step 1 and work through each step one at a time.

# %%
### step 1 - initiate the figure

plt.figure()

# %% [markdown]
# Check the environment...

# %%
# %whos

# %% [markdown]
# But let's continue our journey...let's execute step 1 and step 2.

# %%
### step 1 - initiate the figure

plt.figure()

### step 2 - create the subplot

plt.subplot()

# %% [markdown]
# Review these two steps again...but this time show more of the arguments within step 2.

# %%
### step 1 - initiate the figure

plt.figure()

### step 2 - create the subplot

plt.subplot( 1, 1, 1 ) ### ( number of rows, number of columns, plot index or panel number)

# %%
### step 1 - initiate the figure

plt.figure()

### step 2 - create the subplot

plt.subplot( 2, 1, 1 ) ### ( number of rows, number of columns, plot index or panel number)
plt.subplot( 2, 1, 2 ) ### ( number of rows, number of columns, plot index or panel number)

# %%
### step 1 - initiate the figure

plt.figure()

### step 2 - create the subplot

plt.subplot( 2, 2, 1 ) ### ( number of rows, number of columns, plot index or panel number)
plt.subplot( 2, 2, 2 ) ### ( number of rows, number of columns, plot index or panel number)
plt.subplot( 2, 2, 3 ) ### ( number of rows, number of columns, plot index or panel number)
plt.subplot( 2, 2, 4 ) ### ( number of rows, number of columns, plot index or panel number)

# %% [markdown]
# Let's move to step 3 and POPULATE data within the AXES contained inside the FIGURE.
#
# We will show a simple SINE WAVE as our data.

# %%
np.linspace(0, 10, 100)

# %%
np.sin( np.linspace(0, 10, 100) )

# %%
plt.figure()

plt.subplot(1, 1, 1)

### step 3 - POPULATE data within the AXES contained in a FIGURE
plt.plot( np.sin( np.linspace(0, 10, 100) ) )

# %% [markdown]
# SHOWING the plot removes the weird text that gets displayed to the screen.

# %%
plt.figure()

plt.subplot(1, 1, 1)

plt.plot( np.sin( np.linspace(0, 10, 100) ) )

plt.show()

# %%
# %whos

# %% [markdown]
# The odd MATLAB style workflow comes into play...There is a FIGURE object HIDDEN behind the scenes...

# %%
plt.gcf()

# %%
plt.gca()

# %% [markdown]
# Why am I making the big deal about the FIGURE vs SUBPLOT (AXES)????
#
# Because we can have multiple subplots associated with a single figure!!!!
#
# Let's initiate a single figure that has 2 subplots. One shows the SINE WAVE and another shows a COSINE WAVE.

# %%
plt.figure()

### define 2 subplots contained in this figure
plt.subplot( 2, 1, 1 )

plt.plot( np.sin( np.linspace(0, 10, 100) ) )

### define the SECOND subplot within the figure
plt.subplot( 2, 1, 2 )

plt.plot( np.cos( np.linspace(0, 10, 100) ) )

plt.show()

# %% [markdown]
# Examine this again but only populate data on the 2nd subplot.

# %%
plt.figure()

plt.subplot(2, 1, 1)

plt.subplot(2, 1, 2)

plt.plot( np.cos( np.linspace(0, 10, 100) ) )

plt.show()

# %%
plt.figure()

plt.subplot(2, 1, 1)

plt.subplot(2, 1, 2)

plt.plot( np.sin( np.linspace(0, 10, 100) ) )
plt.plot( np.cos( np.linspace(0, 10, 100) ) )

plt.show()

# %% [markdown]
# We could instead use 1 row and 2 columns of subplots.

# %%
plt.figure()

plt.subplot(1, 2, 1)

plt.plot( np.sin( np.linspace(0, 10, 100) ) )

plt.subplot(1, 2, 2)

plt.plot( np.cos( np.linspace(0, 10, 100) ) )

plt.show()

# %% [markdown]
# Highlight we can control the exact AXES or subplot the data are populated to!

# %%
plt.figure()

plt.subplot(1, 5, 1)

plt.plot( np.sin( np.linspace(0, 10, 100) ) )

plt.subplot(1, 5, 2)

plt.plot( np.cos( np.linspace(0, 10, 100) ) )

plt.show()

# %%
plt.figure()

plt.subplot(1, 5, 1)

plt.plot( np.sin( np.linspace(0, 10, 100) ) )

plt.subplot(1, 5, 5)

plt.plot( np.cos( np.linspace(0, 10, 100) ) )

plt.show()

# %% [markdown]
# We can control the figure size with the `figsize` argument to the `plt.figure()` function!

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 5, 1)

plt.plot( np.sin( np.linspace(0, 10, 100) ) )

plt.subplot(1, 5, 5)

plt.plot( np.cos( np.linspace(0, 10, 100) ) )

plt.show()

# %% [markdown]
# ## Object Oriented Style
#
# Many aspects of the Object Oriented Style figures are the same as the STATEFUL figures. But the way we access or apply functions to them are different!
#
# * step 1: Define the figure and axes objects - create variables!
# * step 2: plot the data within the axes using methods associated with the axes objects!
# * step 3: modify teh axes object attributes if needed
# * step 4: modify the figure object attributes if needed
# * step 5: show the figure
#
# The motivation for the object oriented approach is that the STATEFUL approach works with HIDDEN OBJECTS!!!!
#
# Define variables or objects for the FIGURE and AXES that we are modifying!
#
# The common names for these objects are `fig` and `ax`

# %%
# %whos

# %%
fig, ax = plt.subplots()

# %%
# %whos

# %%
type( fig )

# %%
type( ax )

# %% [markdown]
# The same approach is used even if we want MULTIPLE axes or subplots within a single figure.
#
# Let's create 2 subplots below.

# %%
fig, ax = plt.subplots(2)

# %%
# %whos

# %%
type( ax )

# %%
ax.size

# %%
ax.ndim

# %%
ax.shape

# %%
type( ax[0] )

# %%
type( ax[1] )

# %% [markdown]
# We populate data...or "plot the data"...by calling the METHOD for the corresponding axes element!

# %%
ax[0].plot( np.sin( np.linspace(0, 10, 100) ) )

# %%
fig

# %%
ax[1].plot( np.cos( np.linspace(0, 10, 100) ) )

# %%
fig

# %% [markdown]
# We have a lot of control over the subplots or axes within a figure.
#
# Let's make a figure with 2 rows and 3 columns of subplots.

# %%
fig, axs = plt.subplots(2, 3)

# %%
fig, axs = plt.subplots(2, 3, figsize=(12, 6))

# %% [markdown]
# We can force each subplot to SHARE axes!!!!

# %%
fig, axs = plt.subplots(2, 3, figsize=(12, 6), sharex=True, sharey=True )

# %%
type( axs )

# %%
axs.shape

# %% [markdown]
# We can slice the 2D numpy array just like we slice any 2D numpy array!

# %%
axs[0, 0]

# %%
axs[0, 1]

# %%
print( type( axs[0, 1] ) )

# %% [markdown]
# Use a nested for loop to iterate over each subplot within the figure and display some text.

# %%
axs[1,2].text( 0.5, 0.5, str( (1,2) ), ha='center', fontsize=20)
fig

# %%
for i in range( axs.shape[0] ):
    for j in range( axs.shape[1] ):
        axs[i, j].text( 0.5, 0.5, str( (i,j) ), ha='center', fontsize=20)

# %%
fig

# %% [markdown]
# Put everything in a single cell.

# %%
fig, axs = plt.subplots(2, 3, figsize=(12, 4), sharex=True, sharey=True)

for i in range( axs.shape[0] ):
    for j in range( axs.shape[1] ):
        axs[ i, j ].text( 0.5, 0.5, str( (i, j) ), ha='center', fontsize=20)

plt.show()
